# %% [markdown]
# # แบบฝึกหัดที่แนะนํา

# %%
# Cell 1: Import ฟังก์ชันทั้งหมดจากไฟล์ homework_problems.py
from homework_problems import *

# %% [markdown]
# 1. การคำนวณ Stationary Distribution จากตาราง transition probabilities ให้หา stationary distribution

# %%
dist = calculate_stationary_distribution()
print(f"Stationary Distribution (Sun, Rain): {dist}")
# Out:
# Stationary Distribution (Sun, Rain): [0.75 0.25]

# %% [markdown]
# 2. การ Implement Simple Particle Filter สร้าง particle filter สำหรับปัญหา 1D tracking

# %%
run_simple_particle_filter()

# %% [markdown]
# 3. การวิเคราะห์ HMM จากข้อมูลการสังเกต ให้หาความน่าจะเป็นของสถานะที่ซ่อน

# %%
run_hmm_analysis()
# Out:
# Observation Sequence: ['Symptoms', 'Symptoms', 'Symptoms']
# ----------------------------------------
# Day 1 Belief: P(Healthy)=0.2500, P(Sick)=0.7500
# Day 2 Belief: P(Healthy)=0.1674, P(Sick)=0.8326
# Day 3 Belief: P(Healthy)=0.1540, P(Sick)=0.8460

# %% [markdown]
# 4. การออกแบบ Sensor Model ออกแบบ sensor model สำหรับปัญหา robot localization

# %%
plot_sensor_model()

# %% [markdown]
#  5. การเปรียบเทียบ Filters เปรียบเทียบประสิทธิภาพ Kalman vs Particle Filter

# %%
run_kalman_filter()
